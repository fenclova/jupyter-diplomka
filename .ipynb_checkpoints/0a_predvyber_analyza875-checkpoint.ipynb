# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals
import pandas as pd

# %%
df1 = pd.read_csv(r"C:\fenclova\diplomka\analyza\vysledky\875\Predvyber_vysledky1.csv", delimiter=';').set_index('ID')
df1.head()
# Out:
#     find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# ID
# 1                   0                   20                643.16
# 2                   0                   12                  1.57
# 3                   0                    0                  0.00
# 4                   0                    0                  0.00
# 5                  24                   63                 21.61
#
#     pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  \
# ID
# 1                 3          7653.58               747.59
# 2                19         10267.07              5409.23
# 3                 0          3685.11              4942.49
# 4                 0          1395.98              7101.82
# 5                 9          3580.46              4451.48
#
#     vodni_plohy_rozloha  relief_rozloha  zastavba_rozloha
# ID
# 1              36261.96         5767.13         456577.71
# 2             138528.54         1145.86         129623.91
# ...

# %%
for i in range(1, 17):
    df%s %i
    #= pd.read_csv(r"C:\fenclova\diplomka\analyza\vysledky\875\Predvyber_vysledky2.csv", delimiter=';').set_index('ID')
    #"Predvyber_vysledky%s.csv" % cislo

# %%
frames = [df1, df2]

result = pd.concat(frames)

# %%
result
# Out:
#     find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# ID
# 1                   0                   20                643.16
# 2                   0                   12                  1.57
# 3                   0                    0                  0.00
# 4                   0                    0                  0.00
# 5                  24                   63                 21.61
# 6                   0                    4                294.18
# 7                   0                   64                  1.14
# 8                   0                    6                  2.37
# 9                   0                    0                  0.00
# 10                 60                  130                  1.77
# 11                  0                   30                 36.45
# 12                  0                    4                 28.59
# 13                  0                    0                  0.00
# ...
