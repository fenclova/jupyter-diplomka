# %% [markdown]
# ## Nastavení proměnných
# Zde nastav všechny proměnné:

# %%
# PODMÍNKA: povolit problem pri hledani cesty? 0 = nepovoleno
find_path_problem_podminka == 0

# PODMÍNKA: podíl ploch po rozdělení čtverce vodním tokem
nejlepsi_podil_ploch_max = 3 # 1/4 uzemi

# minimální počet průsečíků vodního toku a mřížky
pocet_pruseciku_min = 10

# PODMÍNKA: délka železnice
zeleznice_delka_min = 2000
zeleznice_delka_max = 15000

# PODMÍNKA: minimální délka rozvodncie III. řádu
rozvodniceIII_delka_min = 500 # v mapě linie 2 cm

# PODMÍNKA: výskyt vodní plochy, minimální délka
vodni_plohy_min = 62500 # 1cm2 v mapě
vodni_plohy_max = 500000 # 8cm2 v mapě = polovina malého čtverečku

# PODMÍNKA: maximalni povolena rozloha skal a povrchové těžby
relief_rozloha_max = 62500 # 1cm2 v mapě

# PODMÍNKA: výskyt zástavby
zastavba_rozloha_min = 62500 # 1cm2 v mapě

# %%
import pandas as pd
df = pd.read_csv(r"C:\fenclova\diplomka\analyza\git_diplomka\predvyber_vysledky\0_predvyber.csv", delimiter=";")
df.head()
# Out:
#    ID  find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# 0   1                  0                   20                643.16
# 1   2                  0                   12                  1.57
# 2   3                  0                    0                  0.00
# 3   4                  0                    0                  0.00
# 4   5                 24                   63                 21.61
#
#    pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  vodni_plohy_rozloha  \
# 0                3          7653.58               747.59             36261.96
# 1               19         10267.07              5409.23            138528.54
# 2                0          3685.11              4942.49            107350.63
# 3                0          1395.98              7101.82                 0.00
# 4                9          3580.46              4451.48             64319.63
#
#    relief_rozloha  zastavba_rozloha
# 0         5767.13         456577.71
# ...

# %%
df.set_index('ID').head()
# Out:
#     find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# ID
# 1                   0                   20                643.16
# 2                   0                   12                  1.57
# 3                   0                    0                  0.00
# 4                   0                    0                  0.00
# 5                  24                   63                 21.61
#
#     pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  \
# ID
# 1                 3          7653.58               747.59
# 2                19         10267.07              5409.23
# 3                 0          3685.11              4942.49
# 4                 0          1395.98              7101.82
# 5                 9          3580.46              4451.48
#
#     vodni_plohy_rozloha  relief_rozloha  zastavba_rozloha
# ID
# 1              36261.96         5767.13         456577.71
# 2             138528.54         1145.86         129623.91
# ...

# %%
# kolik ctvercu ma find_path_problem?
find_path_problem_sum = df['find_path_problem'][df.find_path_problem > 0].shape[0]
find_path_problem_sum
# Out:
# 182L

# %%
# kolik čtverců má podíl ploch v přípustném intervalu?
df[(df.nejlepsi_podil_ploch >=1) &
    (df.nejlepsi_podil_ploch <= 3)].shape
# Out:
# (304, 10)

# %%
# kolik čtverců má podíl ploch v intervalu? AND nebyl problem s vvýběrem?
df[(df.find_path_problem == 0) &
    (df.nejlepsi_podil_ploch >=1) &
    (df.nejlepsi_podil_ploch <= 3)].shape
# Out:
# (244, 10)

# %%
df[(df.find_path_problem == 0) &
    (df.nejlepsi_podil_ploch >=1) & (df.nejlepsi_podil_ploch <= 3) &
    (df.zeleznice_delka >=2000) & (df.zeleznice_delka <= 15000) &
   (df.rozvodniceIII_delka >= 2000) &
   (df.relief_rozloha <= 10000) &
   (df.vodni_plohy_rozloha > 0) &
   (df.zastavba_rozloha > 0)].describe()
# Out:
#                ID  find_path_problem  end_start_kombinace  \
# count   78.000000               78.0            78.000000
# mean   401.628205                0.0            27.948718
# std    216.892523                0.0            52.254844
# min      2.000000                0.0             1.000000
# 25%    240.250000                0.0             7.250000
# 50%    408.500000                0.0            15.500000
# 75%    558.750000                0.0            32.750000
# max    792.000000                0.0           420.000000
#
#        nejlepsi_podil_ploch  pocet_pruseciku  zeleznice_delka  \
# count             78.000000        78.000000        78.000000
# mean               1.758718        18.769231      6340.873718
# std                0.594202         4.398710      3219.819144
# min                1.010000        13.000000      2534.940000
# 25%                1.280000        15.000000      4188.065000
# 50%                1.660000        17.000000      5049.205000
# ...

# %%
df[(df.nejlepsi_podil_ploch >=1) & (df.nejlepsi_podil_ploch <= 3) &
    (df.zeleznice_delka >=2000) & (df.zeleznice_delka <= 15000) &
   (df.rozvodniceIII_delka >= 2000) &
   (df.relief_rozloha <= 10000) &
   (df.vodni_plohy_rozloha > 0) &
   (df.zastavba_rozloha > 0)].describe()
# Out:
#                ID  find_path_problem  end_start_kombinace  \
# count  100.000000         100.000000           100.000000
# mean   404.780000           3.730000            34.680000
# std    217.694605           9.142922            51.269713
# min      2.000000           0.000000             1.000000
# 25%    232.500000           0.000000             8.000000
# 50%    425.000000           0.000000            20.000000
# 75%    557.250000           0.000000            40.000000
# max    813.000000          60.000000           420.000000
#
#        nejlepsi_podil_ploch  pocet_pruseciku  zeleznice_delka  \
# count            100.000000       100.000000       100.000000
# mean               1.741400        18.860000      6024.745200
# std                0.583487         4.369361      3022.699944
# min                1.000000        13.000000      2322.600000
# 25%                1.245000        15.750000      4173.227500
# 50%                1.650000        18.000000      4973.055000
# ...

# %%
df[(df.pocet_pruseciku >= 13) &
    (df.zeleznice_delka >=2000) & 
   (df.zeleznice_delka <= 15000) &
   (df.rozvodniceIII_delka >= 2000) &
   (df.relief_rozloha <= 10000) &
   (df.vodni_plohy_rozloha > 0) &
   (df.zastavba_rozloha > 0)].describe()
# když beru podíl plochy do 3, je min pocet průsečíků = 13
# když nastavím místo plochy počet průsečíků, získám o 69 více čtverců
# Out:
#                ID  find_path_problem  end_start_kombinace  \
# count  147.000000         147.000000           147.000000
# mean   418.122449           3.551020            34.061224
# std    228.263933           8.285309            45.313554
# min      2.000000           0.000000             1.000000
# 25%    211.500000           0.000000            10.000000
# 50%    429.000000           0.000000            21.000000
# 75%    590.000000           0.000000            40.000000
# max    866.000000          60.000000           420.000000
#
#        nejlepsi_podil_ploch  pocet_pruseciku  zeleznice_delka  \
# count            147.000000        147.00000       147.000000
# mean               2.750272         17.77551      5573.791769
# std                1.774825          4.37583      2925.075591
# min                1.000000         13.00000      2035.440000
# 25%                1.395000         14.00000      3959.870000
# 50%                2.040000         16.00000      4689.410000
# ...

# %%
df[(df.pocet_pruseciku >= 10) &
    (df.nejlepsi_podil_ploch >=1) & (df.nejlepsi_podil_ploch <= 5) & # chci dělit plochu řekou
    (df.zeleznice_delka >=500) & # 2 cm v mapě
   #(df.zeleznice_delka <= 15000) & # maximum délky železnice
   (df.rozvodniceIII_delka >= 500) & # 2 cm v mapě
   (df.relief_rozloha <= 5) & # omezit skály a těžbu (nejsou tam vrstevnice)
   (df.vodni_plohy_rozloha > 500) & # chci vodní plochu
   (df.zastavba_rozloha > 500) # chci zástavbu
  ].describe()
# Out:
#                ID  find_path_problem  end_start_kombinace  \
# count  136.000000         136.000000           136.000000
# mean   397.676471           3.367647            31.110294
# std    216.863940           7.267185            32.478066
# min     14.000000           0.000000             1.000000
# 25%    197.000000           0.000000             9.000000
# 50%    427.500000           0.000000            20.500000
# 75%    559.750000           0.000000            42.000000
# max    802.000000          38.000000           162.000000
#
#        nejlepsi_podil_ploch  pocet_pruseciku  zeleznice_delka  \
# count            136.000000       136.000000       136.000000
# mean               2.169485        18.080882      6014.331250
# std                1.036798         4.891497      5512.202048
# min                1.000000        10.000000       591.510000
# 25%                1.317500        14.750000      3005.880000
# 50%                1.850000        17.000000      4455.505000
# ...
