# %%
import pandas as pd
df = pd.read_csv(r"C:\fenclova\diplomka\analyza\git_diplomka\predvyber_vysledky\0_predvyber.csv", delimiter=";")
df.head() # initial few rows
# Out:
#    ID  find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# 0   1                  0                   20                643.16
# 1   2                  0                   12                  1.57
# 2   3                  0                    0                  0.00
# 3   4                  0                    0                  0.00
# 4   5                 24                   63                 21.61
#
#    pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  vodni_plohy_rozloha  \
# 0                3          7653.58               747.59             36261.96
# 1               19         10267.07              5409.23            138528.54
# 2                0          3685.11              4942.49            107350.63
# 3                0          1395.98              7101.82                 0.00
# 4                9          3580.46              4451.48             64319.63
#
#    relief_rozloha  zastavba_rozloha
# 0         5767.13         456577.71
# ...

# %%
rows, columns = df.shape # dimension of csv
print rows, columns
# Out:
# 875 10

# %%
df.head(2) # first few rows
# Out:
#    ID  find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# 0   1                  0                   20                643.16
# 1   2                  0                   12                  1.57
#
#    pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  vodni_plohy_rozloha  \
# 0                3          7653.58               747.59             36261.96
# 1               19         10267.07              5409.23            138528.54
#
#    relief_rozloha  zastavba_rozloha
# 0         5767.13         456577.71
# 1         1145.86         129623.91

# %%
df.tail() # last few rows
# Out:
#       ID  find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# 870  871                  0                    0                   0.0
# 871  872                  0                   10                   0.0
# 872  873                  0                    0                   0.0
# 873  874                  0                    0                   0.0
# 874  875                  0                    0                   0.0
#
#      pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  \
# 870                0          3386.93              5504.67
# 871                0          5022.59              5981.77
# 872                0          5019.25              9075.87
# 873                0          5319.84              5991.45
# 874                0          8356.38               762.32
#
#      vodni_plohy_rozloha  relief_rozloha  zastavba_rozloha
# 870             30637.78         3625.95        1495668.19
# 871            251070.75        13535.81         534737.16
# ...

# %%
df[2:5]
# Out:
#    ID  find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# 2   3                  0                    0                  0.00
# 3   4                  0                    0                  0.00
# 4   5                 24                   63                 21.61
#
#    pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  vodni_plohy_rozloha  \
# 2                0          3685.11              4942.49            107350.63
# 3                0          1395.98              7101.82                 0.00
# 4                9          3580.46              4451.48             64319.63
#
#    relief_rozloha  zastavba_rozloha
# 2            2.00         259425.21
# 3            0.00          17419.58
# 4        56606.64         374180.01

# %%
df.columns
# Out:
# Index([u'ID', u'find_path_problem', u'end_start_kombinace',
#        u'nejlepsi_podil_ploch', u'pocet_pruseciku', u'zeleznice_delka',
#        u'rozvodniceIII_delka', u'vodni_plohy_rozloha', u'relief_rozloha',
#        u'zastavba_rozloha'],
#       dtype='object')

# %%
df.relief_rozloha
df.relief_rozloha.head()
# Out:
# 0     5767.13
# 1     1145.86
# 2        2.00
# 3        0.00
# 4    56606.64
# Name: relief_rozloha, dtype: float64

# %%
type(df['ID'])
# Out:
# pandas.core.series.Series

# %%
df[['ID', 'relief_rozloha']].head()
# Out:
#    ID  relief_rozloha
# 0   1         5767.13
# 1   2         1145.86
# 2   3            2.00
# 3   4            0.00
# 4   5        56606.64

# %%
df['ID'].max() # max, min, mean, std
# Out:
# 875

# %%
df.describe() # statistics for integer data
# Out:
#                ID  find_path_problem  end_start_kombinace  \
# count  875.000000         875.000000           875.000000
# mean   438.000000           3.086857            25.466286
# std    252.735039           8.736506            34.843648
# min      1.000000           0.000000             0.000000
# 25%    219.500000           0.000000             6.000000
# 50%    438.000000           0.000000            16.000000
# 75%    656.500000           0.000000            35.000000
# max    875.000000         116.000000           420.000000
#
#        nejlepsi_podil_ploch  pocet_pruseciku  zeleznice_delka  \
# count            875.000000       875.000000       875.000000
# mean            1680.348629        11.355429      5452.798571
# std            17757.882748         7.465287      5409.768998
# min                0.000000         0.000000         0.000000
# 25%                1.320000         5.000000      2536.830000
# 50%                3.480000        12.000000      4366.110000
# ...

# %%
df['relief_rozloha'].max()
# Out:
# 11236401.64

# %%
# give me 2 columns, where zeleznice_delka >= 2000
newDF1 = df[['ID', 'zeleznice_delka']][df.zeleznice_delka >= 10000]
newDF1.to_csv('new.csv')
newDF1.head()
# Out:
#     ID  zeleznice_delka
# 1    2         10267.07
# 13  14         26657.17
# 26  27         11356.58
# 47  48         10697.59
# 58  59         13673.30

# %%
# a row, where "rozvodniceIII_delka" is maximum
df[df.rozvodniceIII_delka == df.rozvodniceIII_delka.max()]
df[['ID', 'rozvodniceIII_delka']][df.rozvodniceIII_delka == df.rozvodniceIII_delka.max()]
# Out:
#       ID  rozvodniceIII_delka
# 730  731             17385.29

# %% [markdown]
# # Indexy

# %%
df.index # rozsah indexů (0-875, 875 is not included)
# Out:
# RangeIndex(start=0, stop=875, step=1)

# %%
newDF = df.set_index('ID') # create a new data frame, does not modify the original one
newDF.head()
# Out:
#     find_path_problem  end_start_kombinace  nejlepsi_podil_ploch  \
# ID
# 1                   0                   20                643.16
# 2                   0                   12                  1.57
# 3                   0                    0                  0.00
# 4                   0                    0                  0.00
# 5                  24                   63                 21.61
#
#     pocet_pruseciku  zeleznice_delka  rozvodniceIII_delka  \
# ID
# 1                 3          7653.58               747.59
# 2                19         10267.07              5409.23
# 3                 0          3685.11              4942.49
# 4                 0          1395.98              7101.82
# 5                 9          3580.46              4451.48
#
#     vodni_plohy_rozloha  relief_rozloha  zastavba_rozloha
# ID
# 1              36261.96         5767.13         456577.71
# 2             138528.54         1145.86         129623.91
# ...

# %%
newDF.loc[400] # row with index = 400
# Out:
# find_path_problem             0.00
# end_start_kombinace          42.00
# nejlepsi_podil_ploch          1.16
# pocet_pruseciku              25.00
# zeleznice_delka           12724.38
# rozvodniceIII_delka        8901.99
# vodni_plohy_rozloha      179460.61
# relief_rozloha                0.00
# zastavba_rozloha        2139769.44
# Name: 400, dtype: float64
