# %% [markdown]
# ## Předvýběr území na základě limitujících podmínek
# Karolína Fenclová, Diplomová práce
#
# Skript pro analýzu hodnot pro základní kritéria

# %%
# -*- coding: utf-8 -*-
from __future__ import unicode_literals
import pandas as pd

# %%
# soubor 34 tisíc variant = všechny kombinace intersect železnice AND completly within hranice ČR AND UTM33 zone
df = pd.read_csv(r"C:\fenclova\diplomka\analyza\vysledky\big\Nove_predvyber_vysledky34tis.csv").set_index('ID')
df.head()
# Out:
#     zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# ID
# 1           2916.80             268.0            100013.45      13477.08
# 2           1746.48             211.0             75317.79      11445.57
# 3           3037.87             273.0            102853.89      20013.60
# 4           1496.63             236.0           1253150.84       7025.02
# 5           6191.81             193.0            511724.21      15890.52
#
#     relief_rozloha  zastavba_rozloha
# ID
# 1        197106.33         452304.47
# 2        106362.35         598476.56
# 3         27378.37         169553.29
# 4        609169.86         716973.51
# 5        269874.62         317985.96

# %%
df.describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count     34166.000000      34166.000000         3.416600e+04  34166.000000
# mean       5392.621366        119.364397         2.508810e+05  12096.330259
# std        5862.627946         87.677140         4.994635e+05   5793.069204
# min           0.230000          1.000000         1.000000e+00      0.000000
# 25%        2495.820000         54.000000         3.893772e+04   8151.820000
# 50%        4430.760000         98.000000         1.019114e+05  12080.370000
# 75%        6196.270000        162.000000         2.613735e+05  15804.592500
# max       95250.270000        690.000000         1.017666e+07  41613.460000
#
#        relief_rozloha  zastavba_rozloha
# count    3.416600e+04      3.416600e+04
# mean     4.750117e+04      1.411995e+06
# std      3.359728e+05      1.445075e+06
# min      0.000000e+00      5.800000e-01
# 25%      0.000000e+00      5.985002e+05
# 50%      1.979600e+03      9.761296e+05
# 75%      1.709619e+04      1.662835e+06
# max      1.159171e+07      1.535264e+07

# %% [markdown]
# ### Analýza hodnot kritérií pro předvýběr (34 tisíc variant)

# %%
# závislost délky železnice a rozlohy zástavby
a = df[df.zeleznice_delka <= 50000]
ax= a.sort_values(by=['zeleznice_delka']).plot(x='zeleznice_delka', 
                                                                y='zastavba_rozloha', 
                                                                kind='scatter', 
                                                                ylim=0, xlim=0, 
                                                                grid=True)

ax.set_ylabel(r'Rozloha zástavby [m$^2$]') 
# TODO pro graf změnit m2 na km2
ax.set_xlabel('Délka železnice [m]')
# TODO pro graf změnit m na km
# Out:
# Text(0.5,0,u'D\xe9lka \u017eeleznice [m]')

# %%
# histogram délky železnice
d = df.zeleznice_delka[df.zeleznice_delka <= 15000]
dx = (d/1000).hist(bins=100)
dx.set_xlabel('Délka železnice [km]')
dx.set_ylabel('Počet variant')
# TODO: jak nastavit rozsah os u histogramu?
# TODO: jak si poradit s rozdílnou šířkou sloupců?
# Out:
# Text(0,0.5,u'Po\u010det variant')

# %%
# PODMÍNKA: délka železnice
zeleznice_delka_min = 3000
zeleznice_delka_max = 10000

df[(df.zeleznice_delka >= zeleznice_delka_min) & (df.zeleznice_delka <= zeleznice_delka_max)].describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count     20815.000000      20815.000000         2.081500e+04  20815.000000
# mean       5407.233793        117.967668         2.510802e+05  12364.169689
# std        1625.858989         87.364416         4.927752e+05   5724.969691
# min        3000.140000          1.000000         1.000000e+00      0.000000
# 25%        4232.315000         53.000000         4.303593e+04   8528.750000
# 50%        4980.100000         97.000000         1.065517e+05  12357.840000
# 75%        6301.100000        160.000000         2.595220e+05  16034.910000
# max        9999.850000        637.000000         9.779810e+06  41292.720000
#
#        relief_rozloha  zastavba_rozloha
# count    2.081500e+04      2.081500e+04
# mean     4.470903e+04      1.287449e+06
# std      3.107577e+05      1.093313e+06
# min      0.000000e+00      4.043600e+02
# 25%      0.000000e+00      6.243429e+05
# 50%      1.903630e+03      9.979901e+05
# 75%      1.670704e+04      1.608132e+06
# max      1.070742e+07      1.535264e+07

# %%
# histogram rozlohy zástavby
d = df.zastavba_rozloha[df.zastavba_rozloha <= 5*1000*1000] # 5km2
dx = (d/1000/1000).hist(bins=100)
dx.set_xlabel('Rozloha zástavby [km$^2$]')
dx.set_ylabel('Počet variant')
# Out:
# Text(0,0.5,u'Po\u010det variant')

# %%
# PODMÍNKA: výskyt zástavby
zastavba_rozloha_min = 0.2*1000*1000 #0,2 km2 ve skutečnosti (velmi řídké osídlení)
zastavba_rozloha_max = 2*1000*1000   #2km2 ve skutečnosti (1/8 území) 2cm2 v mapě 1 : 50 000 2*(2*500)**2

df[(df.zastavba_rozloha >= zastavba_rozloha_min) & (df.zastavba_rozloha <= zastavba_rozloha_max)].describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count     26635.000000      26635.000000         2.663500e+04  26635.000000
# mean       4237.849545        119.878581         2.387247e+05  12460.291340
# std        2879.848898         88.498321         5.116070e+05   5671.001322
# min           0.230000          1.000000         1.000000e+00      0.000000
# 25%        2228.070000         55.000000         3.496526e+04   8680.950000
# 50%        4209.340000         98.000000         9.164713e+04  12526.690000
# 75%        5494.570000        161.000000         2.337868e+05  16129.020000
# max       58807.290000        690.000000         1.017666e+07  41613.460000
#
#        relief_rozloha  zastavba_rozloha
# count    2.663500e+04      2.663500e+04
# mean     3.917639e+04      9.268750e+05
# std      2.661103e+05      4.472109e+05
# min      0.000000e+00      2.001099e+05
# 25%      0.000000e+00      5.721779e+05
# 50%      1.394580e+03      8.503664e+05
# 75%      1.406489e+04      1.231483e+06
# max      9.731709e+06      1.999912e+06

# %%
# železnice AND zástavba
df[(df.zeleznice_delka >= zeleznice_delka_min) & (df.zeleznice_delka <= zeleznice_delka_max) &
    (df.zastavba_rozloha >= zastavba_rozloha_min) & (df.zastavba_rozloha <= zastavba_rozloha_max)].describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count     16784.000000      16784.000000         1.678400e+04  16784.000000
# mean       5260.653352        117.899428         2.462338e+05  12583.102898
# std        1530.570492         88.400648         5.054949e+05   5682.130985
# min        3000.140000          1.000000         1.000000e+00      0.000000
# 25%        4192.180000         53.000000         3.972783e+04   8810.182500
# 50%        4877.860000         96.000000         1.001702e+05  12627.885000
# 75%        6040.435000        158.000000         2.478518e+05  16265.507500
# max        9996.430000        637.000000         9.779810e+06  41292.720000
#
#        relief_rozloha  zastavba_rozloha
# count    1.678400e+04      1.678400e+04
# mean     3.853450e+04      9.552695e+05
# std      2.620018e+05      4.460329e+05
# min      0.000000e+00      2.001099e+05
# 25%      0.000000e+00      6.011838e+05
# 50%      1.507170e+03      8.902476e+05
# 75%      1.432223e+04      1.262935e+06
# max      9.731709e+06      1.999912e+06

# %%
# histogram rozlohy skal a povrchové těžby
d = df.relief_rozloha[(df.relief_rozloha > 0) & (df.relief_rozloha <= 250*250)]
dx = d.hist(bins=100)
dx.set_xlabel('Rozloha skal a území povrchové těžby [m$^2$]')
dx.set_ylabel('Počet variant')
# Out:
# Text(0,0.5,u'Po\u010det variant')

# %%
# PODMÍNKA: maximalni povolena rozloha skal a povrchové těžby
relief_rozloha_max = 1*250*250 # 1cm2 v mapě 1 : 25 000

df[(df.relief_rozloha <= relief_rozloha_max)].describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count     30331.000000      30331.000000         3.033100e+04  30331.000000
# mean       5254.143186        112.324618         2.354362e+05  12207.920227
# std        5615.852208         82.001656         4.751888e+05   5772.558121
# min           0.230000          1.000000         1.000000e+00      0.000000
# 25%        2455.270000         52.000000         3.759231e+04   8311.130000
# 50%        4394.260000         92.000000         9.802908e+04  12215.890000
# 75%        6081.660000        150.000000         2.461182e+05  15920.945000
# max       95250.270000        612.000000         1.017666e+07  41613.460000
#
#        relief_rozloha  zastavba_rozloha
# count    30331.000000      3.033100e+04
# mean      7445.659614      1.370079e+06
# std      12983.663647      1.373165e+06
# min          0.000000      5.800000e-01
# 25%          0.000000      5.983624e+05
# 50%        646.040000      9.621664e+05
# 75%       8848.325000      1.613815e+06
# max      62490.180000      1.450715e+07

# %%
# histogram rozlohy vodních ploch
d = df.vodni_plohy_rozloha[(df.vodni_plohy_rozloha < 5*500*500)]
dx = d.hist(bins=100)
dx.set_xlabel('Rozloha vodních ploch [m$^2$]')
dx.set_ylabel('Počet variant')
# Out:
# Text(0,0.5,u'Po\u010det variant')

# %%
# PODMÍNKA: výskyt vodní plochy
vodni_plohy_min = 500*500 # 1cm2 v mapě 1 : 50 000 (možno použít i při bližším neurčení, jestli je vodní plocha opravdu ideální nádrž)

df[(df.vodni_plohy_rozloha >= vodni_plohy_min)].describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count      8924.000000       8924.000000         8.924000e+03   8924.000000
# mean       6881.033103         97.261542         7.304966e+05  11426.895309
# std        7818.555803         81.819135         7.946405e+05   5797.328108
# min           1.760000          1.000000         2.500288e+05      0.000000
# 25%        3193.155000         39.000000         3.338222e+05   7312.460000
# 50%        4826.610000         76.000000         4.773444e+05  11270.020000
# 75%        7575.812500        128.000000         7.860588e+05  15133.905000
# max       95250.270000        690.000000         1.017666e+07  41292.720000
#
#        relief_rozloha  zastavba_rozloha
# count    8.924000e+03      8.924000e+03
# mean     5.062525e+04      1.731719e+06
# std      1.597457e+05      1.721401e+06
# min      0.000000e+00      5.800000e-01
# 25%      0.000000e+00      6.526166e+05
# 50%      4.350910e+03      1.137970e+06
# 75%      3.274997e+04      2.135976e+06
# max      5.707755e+06      1.392823e+07

# %%
# histogram délky vodních toků
d = df.dibA02_delka #[(df.vodni_plohy_rozloha < 5*500*500)]
dx = d.hist(bins=100)
dx.set_xlabel('Délka vodních toků DMÚ25 [m]')
dx.set_ylabel('Počet variant')
# zde problém s vypovídající hodnotou dat = některé vodní toky jako vodní plochy
# Out:
# Text(0,0.5,u'Po\u010det variant')

# %%
# PODMÍNKA délka vodních toků (dmú25)
dibA02_delka_min = 5000 # zhruba průměr +- 7000 m
dibA02_delka_max = 20000

df[(df.dibA02_delka >= dibA02_delka_min) & (df.dibA02_delka <= dibA02_delka_max)].describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count     27287.000000      27287.000000         2.728700e+04  27287.000000
# mean       5080.619034        123.292923         2.401093e+05  12333.940397
# std        4775.370902         87.939005         4.356000e+05   3804.454353
# min           0.230000          1.000000         1.000000e+00   5002.170000
# 25%        2452.660000         58.000000         4.108452e+04   9364.020000
# 50%        4410.450000        102.000000         1.028422e+05  12337.830000
# 75%        6074.605000        167.000000         2.589784e+05  15284.445000
# max       71260.670000        690.000000         7.291415e+06  19998.520000
#
#        relief_rozloha  zastavba_rozloha
# count    2.728700e+04      2.728700e+04
# mean     3.580117e+04      1.343851e+06
# std      1.799021e+05      1.244925e+06
# min      0.000000e+00      5.800000e-01
# 25%      0.000000e+00      5.985098e+05
# 50%      2.018130e+03      9.734651e+05
# 75%      1.692846e+04      1.636332e+06
# max      8.481575e+06      1.249052e+07

# %%
# železnice AND zástavba AND reliéf_min AND vodní plocha AND délka dibavod řek

vybrano1 = df[(df.zeleznice_delka >= zeleznice_delka_min) & (df.zeleznice_delka <= zeleznice_delka_max) &
                (df.zastavba_rozloha >= zastavba_rozloha_min) & (df.zastavba_rozloha <= zastavba_rozloha_max)&
                (df.relief_rozloha <= relief_rozloha_max) &
                (df.vodni_plohy_rozloha >= vodni_plohy_min) &
                (df.dibA02_delka >= dibA02_delka_min) & (df.dibA02_delka <= dibA02_delka_max)]
vybrano1.describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count      2928.000000       2928.000000         2.928000e+03   2928.000000
# mean       5291.464344         87.375683         7.099796e+05  12524.921411
# std        1547.467887         64.800598         7.286193e+05   3833.137598
# min        3000.300000          2.000000         2.500425e+05   5016.910000
# 25%        4209.470000         42.000000         3.313262e+05   9501.867500
# 50%        4852.090000         75.000000         4.595832e+05  12664.165000
# 75%        6148.100000        113.000000         7.711696e+05  15528.375000
# max        9996.430000        480.000000         7.291415e+06  19979.540000
#
#        relief_rozloha  zastavba_rozloha
# count     2928.000000      2.928000e+03
# mean      8163.800512      9.579480e+05
# std      13445.219282      4.481918e+05
# min          0.000000      2.001099e+05
# 25%          0.000000      5.975266e+05
# 50%       1342.035000      8.811042e+05
# 75%       9769.167500      1.263395e+06
# max      61746.620000      1.998518e+06

# %%
# oprava chyby (dibavod byly řeky dmú25) > chci i vše menší než podmínka u řek

vybrano1_doplnek1 = df[(df.zeleznice_delka >= zeleznice_delka_min) & (df.zeleznice_delka <= zeleznice_delka_max) &
                (df.zastavba_rozloha >= zastavba_rozloha_min) & (df.zastavba_rozloha <= zastavba_rozloha_max)&
                (df.relief_rozloha <= relief_rozloha_max) &
                (df.vodni_plohy_rozloha >= vodni_plohy_min) &
                #(df.dibA02_delka >= dibA02_delka_min) & # nastaveno jen horní omezení, kvuli dmú25 x dibavod
                 (df.dibA02_delka <= dibA02_delka_min)] # jako doplněk délka < min
vybrano1_doplnek1.describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count       311.000000        311.000000         3.110000e+02    311.000000
# mean       5208.921608         49.054662         9.891691e+05   2813.754277
# std        1578.058219         63.867758         1.464718e+06   1464.722444
# min        3000.140000          2.000000         2.510476e+05      0.000000
# 25%        4167.495000         18.500000         3.185602e+05   1519.650000
# 50%        4841.690000         34.000000         5.274642e+05   3014.180000
# 75%        5881.815000         55.000000         9.351169e+05   4037.160000
# max        9984.520000        470.000000         9.779810e+06   4989.370000
#
#        relief_rozloha  zastavba_rozloha
# count      311.000000      3.110000e+02
# mean      8205.956913      1.087515e+06
# std      13856.173902      4.602863e+05
# min          0.000000      2.006143e+05
# 25%          0.000000      7.111544e+05
# 50%        131.500000      1.088186e+06
# 75%       9913.640000      1.413323e+06
# max      61039.130000      1.995260e+06

# %%
# oprava2 pro území, kde není vodní plocha

### ještě nepočítáno nic navíc pro tato území

vybrano1_bezVodniPlochy = df[
                (df.zeleznice_delka >= zeleznice_delka_min) & (df.zeleznice_delka <= zeleznice_delka_max) &
                (df.zastavba_rozloha >= zastavba_rozloha_min) & (df.zastavba_rozloha <= zastavba_rozloha_max)&
                (df.relief_rozloha <= relief_rozloha_max) 
                &(df.vodni_plohy_rozloha < vodni_plohy_min) # doplněk 2 = vše i bez vodních ploch > 62500
                &(df.dibA02_delka <= dibA02_delka_max) # nastaveno jen horní omezení                    
                      ]
vybrano1_bezVodniPlochy.describe()
# Out:
#        zeleznice_delka  vrstevnice_pocet  vodni_plohy_rozloha  dibA02_delka  \
# count     10464.000000      10464.000000         10464.000000  10464.000000
# mean       5224.948106        117.529817         82309.731529  11630.193430
# std        1510.254794         85.936016         65882.893465   4803.667924
# min        3000.580000          1.000000             1.000000      0.000000
# 25%        4171.167500         55.000000         26605.215000   8531.140000
# 50%        4864.670000         96.000000         67385.020000  12087.105000
# 75%        5965.477500        157.000000        122590.887500  15294.002500
# max        9992.520000        603.000000        249994.680000  19996.230000
#
#        relief_rozloha  zastavba_rozloha
# count    10464.000000      1.046400e+04
# mean      6901.240058      9.549442e+05
# std      12478.527185      4.405811e+05
# min          0.000000      2.004423e+05
# 25%          0.000000      6.078526e+05
# 50%        273.250000      8.950525e+05
# 75%       7807.952500      1.258435e+06
# max      62490.180000      1.999912e+06

# %%
# funkce vrátí 1=True pokud ID splňuje podmínku
def splnuje (radek):
    return 1
    
vybrano1 = vybrano1.apply(splnuje, axis=1).to_frame()
vybrano1.columns = ['predvyber_ANO']
vybrano1.head()
# Out:
#     predvyber_ANO
# ID
# 11              1
# 18              1
# 19              1
# 21              1
# 37              1

# %%
vybrano1_doplnek1 = vybrano1_doplnek1.apply(splnuje, axis=1).to_frame()
vybrano1_doplnek1.columns = ['predvyber_ANO']
vybrano1_doplnek1.head()
# Out:
#      predvyber_ANO
# ID
# 16               1
# 28               1
# 52               1
# 104              1
# 138              1

# %%
vybrano1_bezVodniPlochy = vybrano1_bezVodniPlochy.apply(splnuje, axis=1).to_frame()
vybrano1_bezVodniPlochy.columns = ['bezVodniPlochy']
vybrano1_bezVodniPlochy.head()
# Out:
#     bezVodniPlochy
# ID
# 8                1
# 9                1
# 14               1
# 15               1
# 24               1

# %%
vybrano1.to_csv('0_predvyber_analyza_BIG_true.csv')
# 2928 variant

# %%
vybrano1_doplnek1.to_csv('0_predvyber_analyza_BIG_true_doplnek.csv')
# 311 variant

# %%
vybrano1_bezVodniPlochy.to_csv('0_predvyber_analyza_BIG_true_doplnek2_10tisBezVody.csv')
# 10 464 variant

# %% [markdown]
# ### ? potřeba dopočítat výběr vodního toku (ev. délku vrstevnic) pro 10 000 variant?

# %% [markdown]
# ### 2. výpočet pro 3200 území: rozloha vodních nádrží a délka vrstevnic

# %%
# pro 3200 variant určena rozloha vodních nádrží a délka vrstevnic
df2 = pd.read_csv(r"C:\fenclova\diplomka\analyza\vysledky\Nove_predvyber2_vysledky3200.csv").set_index('ID')
df2.describe()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-28-7155768232d8> in <module>()
#       1 # pro 3200 variant určena rozloha vodních nádrží a délka vrstevnic
# ----> 2 df2 = pd.read_csv(r"C:\fenclova\diplomka\analyza\vysledky\Nove_predvyber2_vysledky3200.csv").set_index('ID')
#       3 df2.describe()
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     707                     skip_blank_lines=skip_blank_lines)
#     708
# --> 709         return _read(filepath_or_buffer, kwds)
#     710
#     711     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     447
#     448     # Create the parser.
# --> 449     parser = TextFileReader(filepath_or_buffer, **kwds)
#     450
#     451     if chunksize or iterator:
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     816             self.options['has_index_names'] = kwds['has_index_names']
#     817
# --> 818         self._make_engine(self.engine)
#     819
#     820     def close(self):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1047     def _make_engine(self, engine='c'):
#    1048         if engine == 'c':
# -> 1049             self._engine = CParserWrapper(self.f, **self.options)
#    1050         else:
#    1051             if engine == 'python':
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1693         kwds['allow_leading_cols'] = self.index_col is not False
#    1694
# -> 1695         self._reader = parsers.TextReader(src, **kwds)
#    1696
#    1697         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# IOError: File C:\fenclova\diplomka\analyza\vysledky\Nove_predvyber2_vysledky3200.csv does not exist

# %%
# histogram rozlohy vodnich nadrzi
d = df2.vodni_nadrz_rozloha[(df2.vodni_nadrz_rozloha >= 100000) & (df2.vodni_nadrz_rozloha <= 2*1000*1000)] 
# 100 000 m2 je podle oka malý rybník a 2*1000*1000 jsou 2 km2 = 1/8 území
dx = d.hist(bins=50)
dx.set_xlabel('Rozloha vodních nádrží [m$^2$]')
dx.set_ylabel('Počet variant')
# TODO jak s měřítkem na osách, rozloha > km2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-f75361543abb> in <module>()
#       1 # histogram rozlohy vodnich nadrzi
# ----> 2 d = df2.vodni_nadrz_rozloha[(df2.vodni_nadrz_rozloha >= 100000) & (df2.vodni_nadrz_rozloha <= 2*1000*1000)]
#       3 # 100 000 m2 je podle oka malý rybník a 2*1000*1000 jsou 2 km2 = 1/8 území
#       4 dx = d.hist(bins=50)
#       5 dx.set_xlabel('Rozloha vodních nádrží [m$^2$]')
#
# NameError: name 'df2' is not defined

# %%
# PODMÍNKA plocha jen vodních nádrží
vodni_nadrz_rozloha_min = 100000 # malý rybník
vodni_nadrz_rozloha_max = 2*1000*1000 # 1/8 území = 2km2

# %%
# histogram délky vrstevnic
d = df2.delka_vrstevnic[(df2.delka_vrstevnic >= 100000) & (df2.delka_vrstevnic <= 300000)] 
dx = d.hist(bins=50)
dx.set_xlabel(r'Délka vrstevnic [m]')
dx.set_ylabel(r'Počet variant')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-85f3490fa68a> in <module>()
#       1 # histogram délky vrstevnic
# ----> 2 d = df2.delka_vrstevnic[(df2.delka_vrstevnic >= 100000) & (df2.delka_vrstevnic <= 300000)]
#       3 dx = d.hist(bins=50)
#       4 dx.set_xlabel(r'Délka vrstevnic [m]')
#       5 dx.set_ylabel(r'Počet variant')
#
# NameError: name 'df2' is not defined

# %%
# PODMÍNKA délka vrstevnic
delka_vrstevnic_min = 100000 # lehce < 25%
delka_vrstevnic_max = 600000 # o něco více než 75%

df2[(df2.delka_vrstevnic >= delka_vrstevnic_min) & 
    (df2.delka_vrstevnic <= delka_vrstevnic_max)].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-129e5f651534> in <module>()
#       3 delka_vrstevnic_max = 600000 # o něco více než 75%
#       4
# ----> 5 df2[(df2.delka_vrstevnic >= delka_vrstevnic_min) &
#       6     (df2.delka_vrstevnic <= delka_vrstevnic_max)].describe()
#
# NameError: name 'df2' is not defined

# %%
# 2000 variant = podmínka vrstevnice AND vodní nádrže
vybrano2 = df2[(df2.delka_vrstevnic >= delka_vrstevnic_min) & 
                #(df2.delka_vrstevnic <= delka_vrstevnic_max) &
                (df2.vodni_nadrz_rozloha >= vodni_nadrz_rozloha_min) & 
                (df2.vodni_nadrz_rozloha <= vodni_nadrz_rozloha_max)]
vybrano2.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-e9ebf5174fee> in <module>()
#       1 # 2000 variant = podmínka vrstevnice AND vodní nádrže
# ----> 2 vybrano2 = df2[(df2.delka_vrstevnic >= delka_vrstevnic_min) &
#       3                 #(df2.delka_vrstevnic <= delka_vrstevnic_max) &
#       4                 (df2.vodni_nadrz_rozloha >= vodni_nadrz_rozloha_min) &
#       5                 (df2.vodni_nadrz_rozloha <= vodni_nadrz_rozloha_max)]
#
# NameError: name 'df2' is not defined

# %%
def splnuje (radek):
    return 1
    
vybrano2 = vybrano2.apply(splnuje, axis=1).to_frame()
vybrano2.columns = ['predvyber2000_ANO']
vybrano2.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-696500058988> in <module>()
#       2     return 1
#       3
# ----> 4 vybrano2 = vybrano2.apply(splnuje, axis=1).to_frame()
#       5 vybrano2.columns = ['predvyber2000_ANO']
#       6 vybrano2.describe()
#
# NameError: name 'vybrano2' is not defined

# %%
vybrano2_df2 = vybrano2.join(df2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-325c4a27a9ae> in <module>()
# ----> 1 vybrano2_df2 = vybrano2.join(df2)
#
# NameError: name 'vybrano2' is not defined

# %%
vybrano2_df2.to_csv('0_predvyber_analyza2000.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-12dff8ca30d9> in <module>()
# ----> 1 vybrano2_df2.to_csv('0_predvyber_analyza2000.csv')
#
# NameError: name 'vybrano2_df2' is not defined

# %% [markdown]
# ### ? oprava: dopočítat vodní tok pro 3200-2000 území AND území bez vodní nádrže?

# %%
# doplněk k 2000 variantám = vodní nádrž < 100 000 m2 (ale již podmínka > 62 500 m2)
vybrano2_doplnek = df2[(df2.delka_vrstevnic >= delka_vrstevnic_min) & 
                #(df2.delka_vrstevnic <= delka_vrstevnic_max) &
                (df2.vodni_nadrz_rozloha < vodni_nadrz_rozloha_min)]
vybrano2_doplnek.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-ca5f9a43b3a5> in <module>()
#       1 # doplněk k 2000 variantám = vodní nádrž < 100 000 m2 (ale již podmínka > 62 500 m2)
# ----> 2 vybrano2_doplnek = df2[(df2.delka_vrstevnic >= delka_vrstevnic_min) &
#       3                 #(df2.delka_vrstevnic <= delka_vrstevnic_max) &
#       4                 (df2.vodni_nadrz_rozloha < vodni_nadrz_rozloha_min)]
#       5 vybrano2_doplnek.describe()
#
# NameError: name 'df2' is not defined

# %%
vybrano2_doplnek = vybrano2_doplnek.apply(splnuje, axis=1).to_frame()
vybrano2_doplnek.columns = ['predvyber326_ANO']
vybrano2_doplnek_df2 = vybrano2_doplnek.join(df2)
vybrano2_doplnek_df2.head()

# %%
vybrano2_doplnek_df2.to_csv('0_predvyber_analyza326.csv')

# %% [markdown]
# ### ??? + intersect s významnou rozvodnicí

# %% [markdown]
# ### 3. výpočet pro 2000 území: vodní tok, který půlí území na 1/2, řády toků

# %%
# TODO: vodní tok, který půlí ideálně na polovinu
df3 = pd.read_csv(r'C:\fenclova\diplomka\analyza\vysledky\Nove_predvyber_VodniTok.csv').set_index("ID")
df3.describe()

# %%
# histogram podilu ploch
d = df3.nejlepsi_podil_ploch[(df3.nejlepsi_podil_ploch <= 5)] 
dx = d.hist(bins=100)
dx.set_xlabel(r'Podíl ploch při rozdělení území vodním tokem')
dx.set_ylabel(r'Počet variant')

# %%
# kolik území podíl plochy na třetiny
df3.nejlepsi_podil_ploch[(df3.nejlepsi_podil_ploch <= 2)].describe()

# %%
# závislost podílu ploch na poštu průsečíků s mřížkou
a = df3[(df3.nejlepsi_podil_ploch <= 5)]
ax= a.plot(x='nejlepsi_podil_ploch', y='pocet_pruseciku', 
                                                                kind='scatter', 
                                                                ylim={10, 35}, xlim={1,5}, 
                                                                grid=True)

ax.set_xlabel('Podíl ploch při rozdělení')
ax.set_ylabel('Počet průsečíků vodního toku s mřížkou')

# >> podíl ploch je důležitý, protože vybere hlavní tok v území
# ale náročnost záleží na počtu průsečíků

# %% [markdown]
# ### TODO: dopočítat znovu i pro výběžky

# %%
# řeky řádovost
reky_delka = pd.read_csv(r'C:\fenclova\diplomka\analyza\vysledky\delka_vodnich_toku_1verze.csv').set_index('ID')
reky_delka.head()

# %%
# funkce sečte kolik řádů má délku větší 500 m
def pocet_radu(radek):
    return len(filter(lambda x: x>500, list(radek)[3:]))

# pro všech 16 dílků spočti součet linii v každém čtverečku
pocet_radu = reky_delka.apply(pocet_radu, axis=1)
reky_delka["pocet_radu"] = pocet_radu

# %%
reky_delka.head()

# %%
df3_reky = df3.join(reky_delka)
df3_reky.tail()

# %%
df3_reky[(df3_reky.nejlepsi_podil_ploch >= 1) & (df3_reky.nejlepsi_podil_ploch <=2)
         & (df3_reky.pocet_pruseciku >= 5) # pojistka pro případ chyby při výpočtech
    & (df3_reky.pocet_radu >=2) # minimálně 2 řády
    & (df3_reky.pocet_radu <=4) # maximum řádů = 4
     & (df3_reky.r0 <= 1000) # mám určené řády pro většinu toků v území
     #& (df3_reky.celkova_delka <= 25000) # omezení délky vodních toků?
    ].describe()
